# %% [markdown]
# # MEMORIA DEL PROYECTO

# %% [markdown]
# <span style="color:yellow; font-size:56px;">Descubriendo el Camino:
# <br> Un Análisis del Inicio en Ciencia de Datos a Través de Datos de Salarios</span>

# %% [markdown]
# ### Abstract

# %% [markdown]
# Iniciar una carrera en ciencia de datos plantea una serie de interrogantes fundamentales. Este proyecto se enfoca en proporcionar respuestas a estas preguntas mediante un análisis exploratorio de datos (EDA) de un conjunto de datos global.
#
# Los resultados revelan tendencias significativas en cuanto a las posiciones más frecuentes, los rangos salariales esperados y el impacto del trabajo remoto en la industria de la ciencia de datos. A través de este estudio, buscamos ofrecer una valiosa guía para aquellos que se embarcan en su viaje profesional en la ciencia de datos, proporcionando información práctica y perspectivas útiles para navegar por este emocionante campo.

# %% [markdown]
# ## Indice
#
# ### 1. [Introducción](#1-introducción)
#
#    - Breve introducción al proyecto y su objetivo.
#    - Explicación del conjunto de datos utilizado y su relevancia para el análisis de salarios en ciencia de datos.
#
# ### 2. [Objetivos](#2-objetivos)
#
#    - Explicación detallada de los objetivos e hipótesis del análisis exploratorio de datos.
#
# ### 3. [Importación y Preprocesamiento de Datos](#3-importación-y-preprocesamiento-de-datos)
#
#    - Importación de bibliotecas de Python necesarias.
#    - Carga de datos.
#    - Limpieza de datos (manejo de valores faltantes, duplicados, etc.).
#    - Transformaciones de datos si es necesario (normalización, codificación, etc.).
#
# ### 4. [Análisis Exploratorio de Datos](#4.-Análisis-Exploratorio-de-Datos)
#
#    - Resumen estadístico de variables clave (salario, experiencia, educación, etc.).
#    - Visualizaciones descriptivas (histogramas, gráficos de barras, diagramas de caja, etc.).
#    - Análisis de correlación entre variables relevantes.
#    - Exploración de tendencias y patrones.
#
# ### 5.[Resultados y Conclusiones](#5.-Resultados-y-Conclusiones)
#
#    - Conclusiones principales del análisis exploratorio de datos.
#    - Recomendaciones basadas en los hallazgos.
#    - Posibles áreas para investigaciones futuras.
#
# ### 6. Recursos
#    - Se incluye al inicio de procesamiento de datos
#
# ### 7. Código Fuente
#    - Código Python utilizado para el análisis exploratorio de datos en formato Jupyter Notebook se incorpora en esta memoria.
#
# ### 8. Referencias
#    - Se ha utilizado la web de Glassdoor para contrastar datos.

# %% [markdown]
# ## 1. Introducción
#
# El campo de la ciencia de datos ofrece un sinfín de oportunidades, pero también plantea una serie de interrogantes para quienes se embarcan en este viaje profesional. ¿Cuáles son las posiciones más comunes para quienes se inician en este campo? ¿Qué expectativas salariales pueden tener los recién llegados? ¿Cómo evoluciona la carrera profesional en este ámbito, y qué papel juega el trabajo remoto en esta industria en crecimiento?
#
# Este Análisis Exploratorio de Datos (EDA) se propone responder a estas preguntas cruciales mediante el análisis de un extenso conjunto de datos global que abarca más de 15.000 salarios recopilados entre 2020 y 2024. Basándonos en nuestras hipótesis, exploraremos las distintas posiciones asociadas al campo de la ciencia de datos, identificaremos las tendencias salariales en diferentes países y examinaremos el impacto del trabajo remoto en la industria.
#
# Ahondaremos en temas emocionantes, como la variabilidad salarial según la ubicación geográfica y el nivel de experiencia, las posiciones de nivel de entrada más demandadas y las implicaciones del trabajo remoto en la compensación salarial, este estudio busca ofrecer una visión integral y práctica para aquellos que se aventuran en su carrera profesional en la ciencia de datos.

# %% [markdown]
# ## 2. Objetivos
#
# El objetivo principal de este análisis exploratorio de datos (EDA) es proporcionar una comprensión detallada de los primeros pasos en la carrera profesional en el campo de la ciencia de datos. Para lograr este objetivo, nos proponemos alcanzar los siguientes objetivos específicos:
#
# ### 2.1 Objetivos Específicos:
#
# 1. **Identificar las Posiciones Más Frecuentes:** Analizar los datos para identificar las posiciones más comunes ocupadas por los profesionales que se inician en el campo de la ciencia de datos. Esto nos permitirá comprender mejor el panorama laboral para los recién llegados a la industria.
#
# 2. **Explorar las Tendencias Salariales:** Investigar las tendencias salariales entre diferentes niveles de experiencia, ubicaciones geográficas y tipos de empleo (tiempo completo, tiempo parcial, contrato, trabajo independiente) para determinar qué factores influyen en los salarios iniciales en ciencia de datos.
#
# 3. **Analizar la Progresión Profesional:** Estudiar la progresión profesional típica en el campo de la ciencia de datos, examinando cómo los salarios cambian a medida que los profesionales adquieren más experiencia en el campo.
#
# 4. **Evaluar el Impacto del Trabajo Remoto:** Investigar el impacto del trabajo remoto en la compensación salarial y en la disponibilidad de oportunidades laborales en la industria de la ciencia de datos. Esto incluye analizar cómo las empresas que ofrecen una mayor proporción de trabajo remoto afectan los salarios y las condiciones laborales.
#
# ### 2.2 Hipótesis:
#
# Basados en nuestra comprensión del campo de la ciencia de datos y los datos disponibles, formulamos las siguientes hipótesis:
#
# 1. **Hipótesis 1:** Los salarios iniciales varían significativamente según factores como la ubicación geográfica, el tipo de empresa y el nivel de experiencia.
#
# 2. **Hipótesis 2:** Los salarios iniciales en ciencia de datos son más altos en países con un fuerte desarrollo tecnológico, como Estados Unidos, Reino Unido o Canadá, en comparación con países en vías de desarrollo.
#
# 3. **Hipótesis 3:** Las posiciones de nivel de entrada en ciencia de datos, como analista de datos, científico de datos junior o ingeniero de datos junior, son las más comunes entre los recién graduados o aquellos con poca experiencia laboral.
#
# 4. **Hipótesis 4:** Las empresas que ofrecen una mayor proporción de trabajo remoto tienden a pagar salarios más altos para los roles de entrada en ciencia de datos, ya que pueden acceder a un pool más amplio de talentos sin las restricciones geográficas.
#
# 5. **Hipótesis 5:** Los salarios iniciales en ciencia de datos tienden a aumentar significativamente con la experiencia, lo que indica una fuerte correlación entre la experiencia laboral y la compensación salarial en este campo.
#
# Al alcanzar estos objetivos y probar estas hipótesis, buscamos proporcionar una visión integral y práctica para aquellos que se inician en su carrera en la ciencia de datos.

# %% [markdown]
# ## 3. Importación y Preprocesamiento de Datos
#    - Importación de bibliotecas de Python necesarias.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %% [markdown]
# - Carga de datos.
#    Los datos provienen de The Global AI, ML, Data Science Salary Index for 2024 en ai-jobs.net y se obtienen como salaries.cvs el 05 de abril de 2024.
#    Este conjunto de datos se publica en el dominio público bajo CC0.

# %%
# Ruta del archivo CSV relativa al directorio actual
ruta = "salaries.csv"

# Cargar el dataset
data = pd.read_csv(ruta)

# Mostrar las primeras filas del dataset para verificar que se haya cargado correctamente
data.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2022               MI              FT                AI Engineer
# 1       2024               MI              FT             Data Scientist
# 2       2024               MI              FT             Data Scientist
# 3       2024               MI              FT  Machine Learning Engineer
# 4       2024               MI              FT  Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  360000             ILS         107093                 IL           100
# 1  172000             USD         172000                 US             0
# 2   75600             USD          75600                 US             0
# 3  265400             USD         265400                 US             0
# 4  127400             USD         127400                 US             0
#
#   company_location company_size
# 0               IL            L
# ...

# %% [markdown]
# fuente_1 = "https://ai-jobs.net/salaries/2024/"
#
# El archivo de descarga básicamente contiene una única tabla con toda la información salarial estructurada de la siguiente manera:
#
# - **work_year**: El año en que se pagó el salario.
#
# - **experience_level**: El nivel de experiencia en el trabajo durante el año, con los siguientes valores posibles:
#   - EN: Nivel de entrada / Junior
#   - MI: Nivel medio / Intermedio
#   - SE: Nivel senior / Experto
#   - EX: Nivel ejecutivo / Director
#
# - **employment_type**: El tipo de empleo para el rol:
#   - PT: Tiempo parcial
#   - FT: Tiempo completo
#   - CT: Contrato
#   - FL: Trabajo independiente
#
# - **job_title**: El puesto trabajado durante el año.
#
# - **salary**: La cantidad total del salario bruto pagado.
#
# - **salary_currency**: La moneda del salario pagado como un código de moneda ISO 4217.
#
# - **salary_in_usd**: El salario en USD (tasa de cambio dividida por la tasa USD promedio del año respectivo) mediante datos estadísticos del BIS y bancos centrales.
#
# - **employee_residence**: El país de residencia principal del empleado durante el año laboral como un código de país ISO 3166.
#
# - **remote_ratio**: La cantidad general de trabajo realizado de forma remota, con los siguientes valores posibles:
#   - 0: Sin trabajo remoto (menos del 20%)
#   - 50: Parcialmente remoto/híbrido
#   - 100: Totalmente remoto (más del 80%)
#
# - **company_location**: El país de la oficina principal del empleador o sucursal contratante como un código de país ISO 3166.
#
# - **company_size**: El número promedio de personas que trabajaron para la empresa durante el año:
#   - S: menos de 50 empleados (pequeña)
#   - M: de 50 a 250 empleados (mediana)
#   - L: más de 250 empleados (grande)

# %% [markdown]
# - Aseguramos la limpieza del dataset

# %%
# Verificar si hay valores nulos en el conjunto de datos
print(data.isnull().sum())
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
#Info del dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15486 entries, 0 to 15485
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           15486 non-null  int64
#  1   experience_level    15486 non-null  object
#  2   employment_type     15486 non-null  object
#  3   job_title           15486 non-null  object
#  4   salary              15486 non-null  int64
#  5   salary_currency     15486 non-null  object
#  6   salary_in_usd       15486 non-null  int64
#  7   employee_residence  15486 non-null  object
#  8   remote_ratio        15486 non-null  int64
#  9   company_location    15486 non-null  object
#  10  company_size        15486 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 1.3+ MB

# %%
# Examinamos la distribución de salarios
# Configurar el tamaño de la figura
plt.figure(figsize=(10, 6))

# Crear histograma de los salarios en USD
sns.histplot(data['salary_in_usd'], kde=True, color='skyblue')
plt.title('Distribución de Salarios en USD')
plt.xlabel('Salario en USD')
plt.ylabel('Frecuencia')
plt.grid(True)

# Mostrar el histograma
plt.show()

# %%
# Calcular estadísticas descriptivas para identificar valores atípicos
data.describe()
# Out:
#           work_year        salary  salary_in_usd  remote_ratio
# count  15486.000000  1.548600e+04   15486.000000  15486.000000
# mean    2023.174545  1.647509e+05  149970.573615     32.497094
# std        0.707413  3.503199e+05   68810.115344     46.406786
# min     2020.000000  1.400000e+04   15000.000000      0.000000
# 25%     2023.000000  1.021250e+05  102000.000000      0.000000
# 50%     2023.000000  1.422000e+05  141525.000000      0.000000
# 75%     2024.000000  1.880000e+05  185975.000000    100.000000
# max     2024.000000  3.040000e+07  800000.000000    100.000000

# %%
# Examinamos el valor máximo por lo elevado que es.
fila_max_salario_usd = data.loc[data['salary_in_usd'] == 800000]

fila_max_salario_usd
# Out:
#       work_year experience_level employment_type     job_title  salary  \
# 1756       2024               MI              FT  AI Architect  800000
#
#      salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 1756             USD         800000                 CA           100
#
#      company_location company_size
# 1756               CA            M

# %%
# Filtrar el DataFrame para incluir solo las filas con la posición "AI Architect" a tiempo completo (FT)
salarios_ai_architect_ft = data[(data['job_title'] == 'AI Architect') & (data['employment_type'] == 'FT')]

# Mostrar los salarios en USD para la posición "AI Architect" a tiempo completo
print(salarios_ai_architect_ft['salary_in_usd'].head(20).sort_values(ascending=False))
# Out:
# 1756    800000
# 1140    449000
# 9224    330000
# 4876    317000
# 7112    305100
# 1916    289000
# 997     285000
# 4877    266000
# 2187    257250
# 3088    208000
# 4830    198650
# 2810    197500
# 498     180000
# 3089    177000
# 1141    173000
# 998     153400
# 7113    146900
# 4831    137000
# 2811    132500
# 2188     99750
# Name: salary_in_usd, dtype: int64

# %% [markdown]
# Aunque el salario de 800000 € es sospechoso, no podemos descartarlo. En cualquier caso más adelante veremos que este puesto de AI Architet, no es relevante para la categoria de principiantes que nos interesa.

# %%
#Verificar valores unicos en las columnas categoricas
categorical_columns = ['experience_level', 'employment_type', 'job_title', 'salary_currency', 'employee_residence', 'company_location', 'company_size']

for column in categorical_columns:
    print(column, data[column].unique())
# Out:
# experience_level ['MI' 'SE' 'EN' 'EX']
# employment_type ['FT' 'PT' 'FL' 'CT']
# job_title ['AI Engineer' 'Data Scientist' 'Machine Learning Engineer'
#  'Data Architect' 'Business Intelligence Analyst' 'Data Engineer'
#  'Data Manager' 'Data Analyst' 'ML Engineer' 'Data Specialist'
#  'Data Product Owner' 'Data Analytics Lead' 'Applied Scientist'
#  'Analytics Engineer' 'Research Scientist' 'Data Operations Manager'
#  'Data Science' 'Business Intelligence Developer' 'Business Intelligence'
#  'Data Modeler' 'Machine Learning Scientist'
#  'Business Intelligence Engineer' 'Robotics Engineer'
#  'Data Management Analyst' 'Data Science Manager' 'Research Engineer'
#  'AI Research Scientist' 'Business Intelligence Manager'
#  'Research Analyst' 'Data Operations Specialist' 'Bear Robotics'
#  'Data Science Consultant' 'Data Analytics Manager' 'BI Developer'
#  'Data Lead' 'Data Infrastructure Engineer' 'Data Operations Associate'
# ...

# %% [markdown]
# Vemos que hay una gran variedad de valores. Examinemos su relevancia para nuestros intereses.

# %%
#Examinemos la distribución pot tipo de trabajo 
# Configurar el tamaño de la figura
plt.figure(figsize=(8, 6))

# Crear la gráfica de distribución
sns.countplot(x='employment_type', data=data, palette='viridis')

# Añadir etiquetas y título
plt.xlabel('Employment Type')
plt.ylabel('Count')
plt.title('Distribution of Employment Types')

# Mostrar la gráfica
plt.show()
# Out:
# C:\Users\ferna\AppData\Local\Temp\ipykernel_4068\2349336929.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='employment_type', data=data, palette='viridis')

# %% [markdown]
# La mayoria de los datos son de trabajo a tiempo completo. Podemos prescindir del resto de categorias.

# %%
# Contar el número de valores únicos en la columna "job_title"
num_valores_unicos_job_title = data['job_title'].nunique()

print("Número de valores únicos para 'job_title':", num_valores_unicos_job_title)
# Out:
# Número de valores únicos para 'job_title': 154

# %% [markdown]
# ## 4. Análisis Exploratorio de Datos

# %%
# Veamos la distribución de valores por Job Title
#Configurar el tamaño de la figura
plt.figure(figsize=(12, 6))

# Crear la gráfica de distribución
sns.countplot(x='job_title', data=data, order = data['job_title'].value_counts().index)

# Rotar las etiquetas del eje x para que sean legibles
plt.xticks(rotation=90)

# Añadir etiquetas y título
plt.xlabel('Job Title')
plt.ylabel('Count')
plt.title('Distribution of Job Titles')

# Mostrar la gráfica
plt.show()

# %% [markdown]
# La amplia mayoria de los valores se agrupan en 4 puestos de trabajo: Data Analiyst, Data Scientist, Data Engineer y Machine Learning Engineer.

# %%
# Contar la cantidad de datos por año
datos_por_año = data['work_year'].value_counts().sort_index(ascending=False)

# Mostrar el resultado
print(datos_por_año)
# Out:
# work_year
# 2024    5019
# 2023    8519
# 2022    1655
# 2021     218
# 2020      75
# Name: count, dtype: int64

# %% [markdown]
# Examinamos 2021 y 2020 con más detalle

# %%
# Filtrar los datos para el año 2021
datos_2021 = data[data['work_year'] == 2021]

# Contar la frecuencia de cada título de trabajo
recuento_job_title_2021 = datos_2021['job_title'].value_counts().head(20)

# Mostrar el resultado
print(recuento_job_title_2021)
# Out:
# job_title
# Data Scientist                       40
# Data Engineer                        37
# Data Analyst                         20
# Machine Learning Engineer            18
# Research Scientist                   10
# Data Science Manager                  6
# Principal Data Scientist              5
# Director of Data Science              5
# Data Science Consultant               5
# Big Data Engineer                     4
# ML Engineer                           4
# BI Data Analyst                       4
# Lead Data Engineer                    3
# Data Architect                        3
# Computer Vision Engineer              3
# Data Analytics Manager                3
# Data Analytics Engineer               3
# Machine Learning Scientist            3
# Head of Data                          3
# Computer Vision Software Engineer     3
# Name: count, dtype: int64

# %%
# Filtrar los datos para el año 2020
datos_2020 = data[data['work_year'] == 2020]

# Contar la frecuencia de cada título de trabajo
recuento_job_title_2020 = datos_2020['job_title'].value_counts().head(20)

# Mostrar el resultado
print(recuento_job_title_2020)
# Out:
# job_title
# Data Scientist                21
# Data Engineer                 13
# Data Analyst                   6
# Machine Learning Engineer      4
# Big Data Engineer              3
# Business Data Analyst          3
# Lead Data Engineer             2
# Staff Data Analyst             2
# Research Scientist             2
# Lead Data Scientist            2
# BI Data Analyst                1
# Machine Learning Scientist     1
# Director of Data Science       1
# AI Scientist                   1
# Computer Vision Engineer       1
# Lead Data Analyst              1
# Principal Data Scientist       1
# Azure Data Engineer            1
# Data Science Consultant        1
# ML Engineer                    1
# Name: count, dtype: int64

# %%
# Filtrar los datos para cada año y contar la frecuencia de cada título de trabajo excluyendo 2020
recuento_job_title_por_año = {}
for año in range(2021, 2025):
    datos_año = data[data['work_year'] == año]
    recuento_job_title_por_año[año] = datos_año['job_title'].value_counts().head(20)

# Crear un DataFrame con los resultados
tabla_recuento_job_title = pd.DataFrame(recuento_job_title_por_año)

# Mostrar la tabla
print(tabla_recuento_job_title)
# Out:
#                                     2021   2022    2023   2024
# job_title
# AI Engineer                          NaN    NaN    47.0   60.0
# AI Scientist                         NaN    8.0     NaN    NaN
# Analytics Engineer                   NaN   56.0   222.0  137.0
# Applied Machine Learning Scientist   NaN    9.0     NaN    NaN
# Applied Scientist                    NaN   18.0   280.0  107.0
# BI Data Analyst                      4.0    NaN     NaN    NaN
# BI Developer                         NaN    NaN    55.0    NaN
# Big Data Engineer                    4.0    NaN     NaN    NaN
# Business Data Analyst                NaN    7.0     NaN    NaN
# Business Intelligence                NaN    NaN     NaN   72.0
# Business Intelligence Analyst        NaN    NaN    78.0   85.0
# Business Intelligence Developer      NaN    NaN     NaN   34.0
# Business Intelligence Engineer       NaN    NaN   164.0   72.0
# Computer Vision Engineer             3.0    NaN     NaN    NaN
# ...

# %%
# Realizar un recuento de cada uno de los títulos de trabajo
recuento_job_title = data['job_title'].value_counts()

# Mostrar el resultado
recuento_job_title.head(30)
# Out:
# job_title
# Data Engineer                               3262
# Data Scientist                              3140
# Data Analyst                                2286
# Machine Learning Engineer                   1618
# Research Scientist                           497
# Analytics Engineer                           415
# Applied Scientist                            405
# Data Architect                               387
# Research Engineer                            289
# Business Intelligence Engineer               236
# Data Science                                 229
# Data Manager                                 202
# ML Engineer                                  171
# Business Intelligence Analyst                163
# Machine Learning Scientist                   130
# Data Science Manager                         116
# Research Analyst                             111
# AI Engineer                                  108
# BI Developer                                  86
# ...

# %%
# Filtrar los datos para el nivel de experiencia "Entry-level"
entry_level_data = data[data['experience_level'] == 'EN']

# Inicializar un diccionario para almacenar el recuento de los títulos de trabajo más frecuentes por año
top_job_titles_by_year = {}

# Iterar sobre los años y calcular el recuento de los títulos de trabajo más frecuentes para cada uno
for year in range(2021, 2025):
    year_data = entry_level_data[entry_level_data['work_year'] == year]
    top_job_titles_by_year[year] = year_data['job_title'].value_counts().head(5)

# Crear un DataFrame con los resultados
tabla_entry_level = pd.DataFrame(top_job_titles_by_year)

# Crear un mapa de calor
plt.figure(figsize=(10, 6))
sns.heatmap(tabla_entry_level, annot=True, cmap="YlGnBu", fmt='g')
plt.title('Top 5 Empleos para Principiantes por Año')
plt.xlabel('Año')
plt.ylabel('Puesto de trabajo')
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Crear la nube de palabras
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(recuento_job_title)

# Mostrar la nube de palabras
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Nube de Palabras de Puestos de Trabajo')
plt.show()

# %%
# Filtrar los datos para el nivel de experiencia "Entry level"
entry_level_data = data[data['experience_level'] == 'EN']

# Contar la frecuencia de cada título de trabajo para entry level
frecuencia_entry_level = entry_level_data['job_title'].value_counts()

# Crear la nube de palabras
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(frecuencia_entry_level)

# Mostrar la nube de palabras
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Puestos más frecuentes para Principiantes')
plt.show()

# %% [markdown]
# Creamos dataset solo con los datos de Full time job, años 22, 23 y 24, para los 'Data Analyst', 'Data Scientist', 'Data Engineer', 'Machine Learning Engineer' y lo llamamos df_filtrado. Luego lo exportaremos como csv y se aportará a la documentación.

# %%
# Filtrar el DataFrame para incluir solo los datos de FT en los años 2022, 2023 y 2024, y para los títulos de trabajo específicos
filtro = ((data['employment_type'] == 'FT') & 
          (data['work_year'].isin([2022, 2023, 2024])) &
          (data['job_title'].isin(['Data Analyst', 'Data Scientist', 'Data Engineer', 'Machine Learning Engineer'])))

df_filtrado = data.loc[filtro]

# Mostrar el DataFrame resultante
df_filtrado
# Out:
#        work_year experience_level employment_type                  job_title  \
# 1           2024               MI              FT             Data Scientist
# 2           2024               MI              FT             Data Scientist
# 3           2024               MI              FT  Machine Learning Engineer
# 4           2024               MI              FT  Machine Learning Engineer
# 7           2024               EN              FT             Data Scientist
# ...          ...              ...             ...                        ...
# 15210       2022               MI              FT             Data Scientist
# 15217       2022               MI              FT             Data Scientist
# 15219       2022               MI              FT              Data Engineer
# 15220       2022               MI              FT             Data Scientist
# 15238       2022               EN              FT              Data Engineer
#
# ...

# %%
# Especifica la ruta donde quieres guardar el archivo CSV
ruta_csv = 'df_filtrado.csv'

# Guarda el DataFrame en un archivo CSV
df_filtrado.to_csv(ruta_csv, index=False)

print("El DataFrame df_filtrado se ha guardado correctamente en", ruta_csv)
# Out:
# El DataFrame df_filtrado se ha guardado correctamente en df_filtrado.csv

# %%
# Calcular los datos por país
datos_por_pais = df_filtrado.groupby('employee_residence').size()

# Ordenar los resultados en orden descendente
datos_por_pais_ordenados = datos_por_pais.sort_values(ascending=False)

# Mostrar los resultados
print(datos_por_pais_ordenados)
# Out:
# employee_residence
# US    8978
# GB     437
# CA     272
# ES     103
# DE      33
# FR      30
# AU      26
# IN      20
# NL      19
# LT      16
# PT      13
# BR      12
# LV      12
# CO      12
# IE      11
# GR      11
# EE      10
# EG      10
# MX       9
# AR       8
# AT       7
# PL       7
# CH       7
# IT       5
# SI       4
# PR       4
# VN       4
# UA       4
# PH       3
# UZ       2
# NZ       2
# TR       2
# NO       2
# ZA       2
# AE       2
# BE       2
# CF       2
# HR       2
# KW       1
# SG       1
# AM       1
# UG       1
# CR       1
# CY       1
# TH       1
# EC       1
# RU       1
# JP       1
# RO       1
# FI       1
# HK       1
# PK       1
# HU       1
# PE       1
# ID       1
# AD       1
# dtype: int64

# %%
# Filtrar los datos para empleados de nivel de entrada en España
filtro_es_entry_level = (df_filtrado['employee_residence'] == 'ES') & (df_filtrado['experience_level'] == 'EN')
datos_es_entry_level = df_filtrado[filtro_es_entry_level]

# Calcular el recuento de valores únicos en la columna 'salary_currency'
recuento_currency = datos_es_entry_level['salary_currency'].value_counts()

print("Recuento de currency para empleados de nivel de entrada en España:")
print(recuento_currency)
# Out:
# Recuento de currency para empleados de nivel de entrada en España:
# salary_currency
# EUR    6
# Name: count, dtype: int64

# %%
# Filtrar los datos para empleados de nivel de entrada en España
filtro_es_entry_level_data = (data['employee_residence'] == 'ES') & (data['experience_level'] == 'EN')
datos_es_entry_level_data = data[filtro_es_entry_level_data]

# Calcular el recuento de valores únicos en la columna 'salary_currency'
recuento_currency_data = datos_es_entry_level_data['salary_currency'].value_counts()

print("Recuento de currency para empleados de nivel de entrada en España (DataFrame 'data'):")
print(recuento_currency_data)
# Out:
# Recuento de currency para empleados de nivel de entrada en España (DataFrame 'data'):
# salary_currency
# EUR    9
# Name: count, dtype: int64

# %% [markdown]
# Visualicemos el total de datos para Entry level España dado que son solo 9.
# Vemos que la diferencia entre los datos totales y los filtrados es pequeña y se debe a un Data Analyst part time, un Data Science Consultant y un Business Analyst.

# %%
datos_es_entry_level_data
# Out:
#        work_year experience_level employment_type                job_title  \
# 4322        2024               EN              FT             Data Analyst
# 4323        2024               EN              FT             Data Analyst
# 6226        2023               EN              FT           Data Scientist
# 6227        2023               EN              FT           Data Scientist
# 11012       2023               EN              FT            Data Engineer
# 12272       2023               EN              FT    Business Data Analyst
# 13477       2022               EN              PT             Data Analyst
# 13998       2022               EN              FT  Data Science Consultant
# 14664       2022               EN              FT           Data Scientist
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 4322    26000             EUR          28888                 ES             0
# ...

# %% [markdown]
# <span style="color:yellow; font-size:20px;">NOTA DE ATENCIÓN: Dada la escasez de datos comprobamos con fuentes externas como Glassdoor que los resultados a nivel salarial son coherentes.
# <br>También usaremos los datos mayoritarios de Estados Unidos (US) para extrapolar conclusiones.
# <br>Ver Presentación para comprobación.</span>

# %% [markdown]
# Calculo de salario medio, minimo y máximo por puesto usando la función agg de pandas.

# %%
# Filtrar los datos para España (ES), nivel de entrada (Entry level) y por título de trabajo
filtro_es_entry_level = (df_filtrado['employee_residence'] == 'ES') & (df_filtrado['experience_level'] == 'EN')

# Aplicar el filtro
datos_es_entry_level = df_filtrado[filtro_es_entry_level]

# Calcular las estadísticas para salario por título de trabajo
estadisticas_salario_por_job_title = datos_es_entry_level.groupby('job_title')['salary'].agg(['mean', 'min', 'max'])

# Mostrar los resultados
print(estadisticas_salario_por_job_title)
# Out:
#                    mean    min    max
# job_title
# Data Analyst    23500.0  21000  26000
# Data Engineer   38000.0  38000  38000
# Data Scientist  33000.0  29000  40000

# %% [markdown]
# Comparemos la evolución de los salarios con la experiencia en US y ES.

# %%
# Filtrar los datos para Data Analyst en el año 2022 y excluir la categoría "EX"
filtro_data_analyst_2022 = (data['job_title'] == 'Data Analyst') & (data['work_year'] == 2022) & (data['experience_level'] != 'EX')
datos_data_analyst_2022 = data[filtro_data_analyst_2022]

# Filtrar los datos para Data Analyst en Estados Unidos y España
datos_data_analyst_us = datos_data_analyst_2022[datos_data_analyst_2022['employee_residence'] == 'US']
datos_data_analyst_es = datos_data_analyst_2022[datos_data_analyst_2022['employee_residence'] == 'ES']

# Mapear los valores de experiencia a etiquetas más legibles
etiquetas_experiencia = {'EN': 'Junior', 'MI': 'Medio', 'SE': 'Senior'}

# Calcular la media salarial por nivel de experiencia para Data Analyst en Estados Unidos y España
media_salarios_us = datos_data_analyst_us.groupby('experience_level')['salary_in_usd'].mean().rename(etiquetas_experiencia)
media_salarios_es = datos_data_analyst_es.groupby('experience_level')['salary_in_usd'].mean().rename(etiquetas_experiencia)

# Crear la gráfica de barras
fig, ax = plt.subplots(figsize=(10, 6))

# Añadir barras para Estados Unidos y España
ax.bar(media_salarios_us.index, media_salarios_us.values, width=0.4, label='US')
ax.bar([i + 0.4 for i in range(len(media_salarios_es))], media_salarios_es.values, width=0.4, label='ES')

# Añadir etiquetas y título
ax.set_xticks([i + 0.2 for i in range(len(media_salarios_us))])
ax.set_xticklabels(media_salarios_us.index)
ax.set_xlabel('Nivel de Experiencia')
ax.set_ylabel('Salario Medio (USD)')
ax.set_title('Media Salarial por Nivel de Experiencia para Data Analyst en 2022 (US vs ES)')
ax.legend()

# Mostrar la gráfica
plt.tight_layout()
plt.show()

# %%
# Filtrar los datos para Data Analyst en el año 2022 y excluir la categoría "EX"
filtro_data_analyst_2022 = (data['job_title'] == 'Data Analyst') & (data['work_year'] == 2022) & (data['experience_level'] != 'EX')
datos_data_analyst_2022 = data[filtro_data_analyst_2022]

# Filtrar los datos para Data Analyst en Estados Unidos y España
datos_data_analyst_us = datos_data_analyst_2022[datos_data_analyst_2022['employee_residence'] == 'US']
datos_data_analyst_es = datos_data_analyst_2022[datos_data_analyst_2022['employee_residence'] == 'ES']

# Mapear los valores de experiencia a etiquetas más legibles
etiquetas_experiencia = {'EN': 'Junior', 'MI': 'Medio', 'SE': 'Senior'}

# Calcular la media salarial por nivel de experiencia para Data Analyst en Estados Unidos y España
media_salarios_us = datos_data_analyst_us.groupby('experience_level')['salary_in_usd'].mean().rename(etiquetas_experiencia)
media_salarios_es = datos_data_analyst_es.groupby('experience_level')['salary_in_usd'].mean().rename(etiquetas_experiencia)

# Crear la gráfica de barras
fig, ax = plt.subplots(figsize=(10, 6))

# Ajustar el orden y los colores de las barras
index = np.arange(len(media_salarios_us))
bar_width = 0.35

# Añadir barras para Estados Unidos y España
rects1 = ax.bar(index, media_salarios_us.values, bar_width, label='US', color='blue')
rects2 = ax.bar(index + bar_width, media_salarios_es.values, bar_width, label='ES', color='orange')

# Añadir etiquetas y título
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(media_salarios_us.index)
ax.set_xlabel('Nivel de Experiencia')
ax.set_ylabel('Salario Medio (USD)')
ax.set_title('Media Salarial por Nivel de Experiencia para Data Analyst en 2022 (US vs ES)')
ax.legend()

# Mostrar la gráfica
plt.tight_layout()
plt.show()

# %%
# Filtrar el conjunto de datos para Data Analyst, US y ES, solo para el año 2022 y los niveles de experiencia EN, MI y SE
data_analyst_2022_us_es = df_filtrado[(df_filtrado['job_title'] == 'Data Analyst') &
                                      (df_filtrado['employee_residence'].isin(['US', 'ES'])) &
                                      (df_filtrado['work_year'] == 2022) &
                                      (df_filtrado['experience_level'].isin(['EN', 'MI', 'SE']))]

# Calcular la media salarial por nivel de experiencia y país
media_salarios_por_nivel_experiencia_y_pais_2022 = data_analyst_2022_us_es.groupby(['experience_level', 'employee_residence'])['salary_in_usd'].mean().unstack()

# Graficar los resultados
media_salarios_por_nivel_experiencia_y_pais_2022.plot(kind='bar', figsize=(10, 6))
plt.title('Media Salarial por Nivel de Experiencia para Data Analyst en 2022 (US vs ES)')
plt.xlabel('Nivel de Experiencia')
plt.ylabel('Media Salarial (USD)')
plt.xticks(ticks=[0, 1, 2], labels=['Junior', 'Medio', 'Senior'], rotation=45)  # Cambiar los títulos del eje X
plt.legend(title='País')
plt.grid(axis='y')

# Mostrar la gráfica
plt.tight_layout()
plt.show()

# %% [markdown]
# Usando solo los datos de US calculemos los salarios medios por nivel de experiencia y tamaño de empresa para los distintos puestos de estudio a fin de ver si hay diferencias.

# %%
# Filtrar el conjunto de datos para incluir solo datos de US
data_us = df_filtrado[df_filtrado['employee_residence'] == 'US']

# Agrupar los datos por puesto, tipo de empresa y nivel de experiencia, y calcular el salario medio
salarios_medios_us = data_us.groupby(['job_title', 'company_size', 'experience_level'])['salary_in_usd'].mean().round(2)

# Mostrar los resultados
print(salarios_medios_us)
# Out:
# job_title                  company_size  experience_level
# Data Analyst               L             EN                   68362.50
#                                          MI                   95875.00
#                                          SE                  143033.33
#                            M             EN                   91741.54
#                                          EX                  116840.91
#                                          MI                  103536.52
#                                          SE                  123461.82
#                            S             EN                   55000.00
#                                          MI                   58000.00
#                                          SE                  106250.00
# Data Engineer              L             EN                   96250.00
#                                          MI                  142150.40
# ...

# %%
# Datos proporcionados
salarios = {
    ('Data Analyst', 'L', 'EN'): 68362.50,
    ('Data Analyst', 'L', 'MI'): 95875.00,
    ('Data Analyst', 'L', 'SE'): 143033.33,
    ('Data Analyst', 'M', 'EN'): 91627.69,
    ('Data Analyst', 'M', 'MI'): 103536.52,
    ('Data Analyst', 'M', 'SE'): 123431.70,
    ('Data Analyst', 'S', 'EN'): 44660.00,
    ('Data Analyst', 'S', 'MI'): 58000.00,
    ('Data Analyst', 'S', 'SE'): 106250.00,
}

# Preparar los datos para la gráfica
tamaños_empresa = ['L', 'M', 'S']
niveles_experiencia = ['EN', 'MI', 'SE']

salarios_por_tamaño_empresa = {tamaño: [] for tamaño in tamaños_empresa}

for tamaño_empresa in tamaños_empresa:
    for nivel_experiencia in niveles_experiencia:
        if nivel_experiencia != 'EX':
            salario = salarios[('Data Analyst', tamaño_empresa, nivel_experiencia)]
            salarios_por_tamaño_empresa[tamaño_empresa].append(salario)

# Crear la gráfica de barras
fig, ax = plt.subplots(figsize=(10, 6))

bar_width = 0.25
index = range(len(niveles_experiencia))

for i, tamaño_empresa in enumerate(tamaños_empresa):
    ax.bar([pos + i * bar_width for pos in index], salarios_por_tamaño_empresa[tamaño_empresa], 
           bar_width, label=f'Tamaño {tamaño_empresa}')

ax.set_xlabel('Nivel de Experiencia')
ax.set_ylabel('Salario Medio')
ax.set_title('Salario Medio por Tamaño de Empresa y Nivel de Experiencia para Data Analyst')
ax.set_xticks([pos + 0.5 for pos in index])
ax.set_xticklabels(niveles_experiencia)
ax.legend()

plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
#Salario Medio por Tamaño de Empresa y Nivel de Experiencia para Data Engineer
# Datos proporcionados
salarios_data_engineer = {
    ('Data Engineer', 'L', 'EN'): 96250.00,
    ('Data Engineer', 'L', 'MI'): 142150.40,
    ('Data Engineer', 'L', 'SE'): 164628.32,
    ('Data Engineer', 'M', 'EN'): 111265.20,
    ('Data Engineer', 'M', 'EX'): 193846.49,
    ('Data Engineer', 'M', 'MI'): 130342.99,
    ('Data Engineer', 'M', 'SE'): 160537.15,
    ('Data Engineer', 'S', 'EN'): 65000.00,
}

# Preparar los datos para la gráfica
tamaños_empresa = ['L', 'M', 'S']
niveles_experiencia = ['EN', 'MI', 'SE']

salarios_por_tamaño_empresa = {tamaño: [] for tamaño in tamaños_empresa}

for tamaño_empresa in tamaños_empresa:
    for nivel_experiencia in niveles_experiencia:
        if (nivel_experiencia != 'EX') and ((('Data Engineer', tamaño_empresa, nivel_experiencia)) in salarios_data_engineer):
            salario = salarios_data_engineer[('Data Engineer', tamaño_empresa, nivel_experiencia)]
            salarios_por_tamaño_empresa[tamaño_empresa].append(salario)
        else:
            salarios_por_tamaño_empresa[tamaño_empresa].append(0)  # Agregar 0 si no hay salario para la combinación

# Crear la gráfica de barras
fig, ax = plt.subplots(figsize=(10, 6))

bar_width = 0.25
index = range(len(niveles_experiencia))

for i, tamaño_empresa in enumerate(tamaños_empresa):
    ax.bar([pos + i * bar_width for pos in index], salarios_por_tamaño_empresa[tamaño_empresa], 
           bar_width, label=f'Tamaño {tamaño_empresa}')

ax.set_xlabel('Nivel de Experiencia')
ax.set_ylabel('Salario Medio')
ax.set_title('Salario Medio por Tamaño de Empresa y Nivel de Experiencia para Data Engineer')
ax.set_xticks([pos + 0.5 for pos in index])
ax.set_xticklabels(niveles_experiencia)
ax.legend()

plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# Es curioso observar que no hay datos de este puesto para pequeñas empresas en niveles MI y SE lo que puede indicar que las grandes y medias acaparan este puesto de Data Engineer.

# %%
# Salario Medio por Tamaño de Empresa y Nivel de Experiencia para Data Scientist
# Datos proporcionados
salarios_data_scientist = {
    ('Data Scientist', 'L', 'EN'): 87333.33,
    ('Data Scientist', 'L', 'MI'): 156347.06,
    ('Data Scientist', 'L', 'SE'): 163609.60,
    ('Data Scientist', 'M', 'EN'): 108016.35,
    ('Data Scientist', 'M', 'EX'): 184471.88,
    ('Data Scientist', 'M', 'MI'): 137029.37,
    ('Data Scientist', 'M', 'SE'): 173286.67,
    ('Data Scientist', 'S', 'EN'): 110000.00,
    ('Data Scientist', 'S', 'SE'): 139250.00,
}

# Preparar los datos para la gráfica
tamaños_empresa = ['L', 'M', 'S']
niveles_experiencia = ['EN', 'MI', 'SE']

salarios_por_tamaño_empresa = {tamaño: [] for tamaño in tamaños_empresa}

for tamaño_empresa in tamaños_empresa:
    for nivel_experiencia in niveles_experiencia:
        if (nivel_experiencia != 'EX') and ((('Data Scientist', tamaño_empresa, nivel_experiencia)) in salarios_data_scientist):
            salario = salarios_data_scientist[('Data Scientist', tamaño_empresa, nivel_experiencia)]
            salarios_por_tamaño_empresa[tamaño_empresa].append(salario)
        else:
            salarios_por_tamaño_empresa[tamaño_empresa].append(0)  # Agregar 0 si no hay salario para la combinación

# Crear la gráfica de barras
fig, ax = plt.subplots(figsize=(10, 6))

bar_width = 0.25
index = range(len(niveles_experiencia))

for i, tamaño_empresa in enumerate(tamaños_empresa):
    ax.bar([pos + i * bar_width for pos in index], salarios_por_tamaño_empresa[tamaño_empresa], 
           bar_width, label=f'Tamaño {tamaño_empresa}')

ax.set_xlabel('Nivel de Experiencia')
ax.set_ylabel('Salario Medio')
ax.set_title('Salario Medio por Tamaño de Empresa y Nivel de Experiencia para Data Scientist')
ax.set_xticks([pos + 0.5 for pos in index])
ax.set_xticklabels(niveles_experiencia)
ax.legend()

plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
# Salario Medio por Tamaño de Empresa y Nivel de Experiencia para Machine Learning Engineer
# Datos proporcionados
salarios_machine_learning_engineer = {
    ('Machine Learning Engineer', 'L', 'EN'): 99000.00,
    ('Machine Learning Engineer', 'L', 'MI'): 174200.00,
    ('Machine Learning Engineer', 'L', 'SE'): 182855.00,
    ('Machine Learning Engineer', 'M', 'EN'): 126647.71,
    ('Machine Learning Engineer', 'M', 'EX'): 235030.56,
    ('Machine Learning Engineer', 'M', 'MI'): 174593.39,
    ('Machine Learning Engineer', 'M', 'SE'): 200845.66,
    ('Machine Learning Engineer', 'S', 'EN'): 108000.00,
    ('Machine Learning Engineer', 'S', 'MI'): 136666.67,
}

# Preparar los datos para la gráfica
tamaños_empresa = ['L', 'M', 'S']
niveles_experiencia = ['EN', 'MI', 'SE']

salarios_por_tamaño_empresa = {tamaño: [] for tamaño in tamaños_empresa}

for tamaño_empresa in tamaños_empresa:
    for nivel_experiencia in niveles_experiencia:
        if (nivel_experiencia != 'EX') and ((('Machine Learning Engineer', tamaño_empresa, nivel_experiencia)) in salarios_machine_learning_engineer):
            salario = salarios_machine_learning_engineer[('Machine Learning Engineer', tamaño_empresa, nivel_experiencia)]
            salarios_por_tamaño_empresa[tamaño_empresa].append(salario)
        else:
            salarios_por_tamaño_empresa[tamaño_empresa].append(0)  # Agregar 0 si no hay salario para la combinación

# Crear la gráfica de barras
fig, ax = plt.subplots(figsize=(10, 6))

bar_width = 0.25
index = range(len(niveles_experiencia))

for i, tamaño_empresa in enumerate(tamaños_empresa):
    ax.bar([pos + i * bar_width for pos in index], salarios_por_tamaño_empresa[tamaño_empresa], 
           bar_width, label=f'Tamaño {tamaño_empresa}')

ax.set_xlabel('Nivel de Experiencia')
ax.set_ylabel('Salario Medio')
ax.set_title('Salario Medio por Tamaño de Empresa y Nivel de Experiencia para Machine Learning Engineer')
ax.set_xticks([pos + 0.5 for pos in index])
ax.set_xticklabels(niveles_experiencia)
ax.legend()

plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# Dando un paso atras y ampliando los datos considerados podemos observar otras posiciones demandas para principiantes en los distintos años.

# %%
# Filtrar los datos originales para incluir solo los años 2021, 2022, 2023 y 2024 y el nivel de experiencia "Entry level"
datos_entry_level_2021_2024 = data[(data['work_year'].isin([2021, 2022, 2023, 2024])) & (data['experience_level'] == 'EN')]

# Inicializar un diccionario para almacenar los títulos de trabajo más frecuentes para cada año y nivel de experiencia
top_titulos_entry_level_por_año = {}

# Iterar sobre cada año y encontrar los 5 títulos de trabajo más frecuentes para el nivel de experiencia "Entry level"
for año in [2021, 2022, 2023, 2024]:
    # Filtrar los datos para el año actual
    datos_año_actual = datos_entry_level_2021_2024[datos_entry_level_2021_2024['work_year'] == año]
    # Contar la frecuencia de cada título de trabajo
    frecuencia_titulos = datos_año_actual['job_title'].value_counts()
    # Obtener los 5 títulos de trabajo más frecuentes
    top_titulos = frecuencia_titulos.head(5).index.tolist()
    # Almacenar los títulos de trabajo más frecuentes para el año actual en el diccionario
    top_titulos_entry_level_por_año[año] = top_titulos

# Construir un nuevo DataFrame con los años y los 5 títulos de trabajo más frecuentes para el nivel de experiencia "Entry level"
nuevo_dataset_entry_level = pd.DataFrame(top_titulos_entry_level_por_año)

# Mostrar el nuevo dataset para el nivel de experiencia "Entry level"
nuevo_dataset_entry_level
# Out:
#                         2021                       2022                2023  \
# 0             Data Scientist             Data Scientist        Data Analyst
# 1              Data Engineer              Data Engineer      Data Scientist
# 2  Machine Learning Engineer               Data Analyst       Data Engineer
# 3               Data Analyst  Machine Learning Engineer    Research Analyst
# 4    Data Science Consultant               AI Scientist  Research Scientist
#
#                             2024
# 0                   Data Analyst
# 1               Research Analyst
# 2  Business Intelligence Analyst
# 3                 Data Scientist
# 4                  Data Engineer

# %%
# Filtrar los datos originales para incluir solo los años 2021, 2022, 2023 y 2024 y el nivel de experiencia "Entry level"
datos_entry_level_2021_2024 = data[(data['work_year'].isin([2021, 2022, 2023, 2024])) & (data['experience_level'] == 'EN')]

# Inicializar una lista para almacenar las filas del nuevo conjunto de datos
filas_nuevo_dataset_entry_level = []

# Iterar sobre cada año y encontrar los 5 títulos de trabajo más frecuentes para el nivel de experiencia "Entry level"
for año in [2021, 2022, 2023, 2024]:
    # Filtrar los datos para el año actual
    datos_año_actual = datos_entry_level_2021_2024[datos_entry_level_2021_2024['work_year'] == año]
    # Contar la frecuencia de cada título de trabajo
    frecuencia_titulos = datos_año_actual['job_title'].value_counts()
    # Obtener los 5 títulos de trabajo más frecuentes
    top_titulos = frecuencia_titulos.head(5)
    # Calcular la frecuencia total de títulos de trabajo para el año actual
    frecuencia_total = frecuencia_titulos.sum()
    # Calcular el porcentaje de frecuencia para cada título de trabajo y agregarlo a la lista de filas
    for titulo, frecuencia in top_titulos.items():
        porcentaje = (frecuencia / frecuencia_total) * 100
        filas_nuevo_dataset_entry_level.append({'Job Title': titulo, f'Año {año} (%)': porcentaje})

# Construir el nuevo DataFrame con los datos de las filas
nuevo_dataset_entry_level = pd.DataFrame(filas_nuevo_dataset_entry_level).round(2)

# Mostrar el nuevo dataset para el nivel de experiencia "Entry level" con los nombres de los job titles y sus porcentajes de frecuencia
nuevo_dataset_entry_level
# Out:
#                         Job Title  Año 2021 (%)  Año 2022 (%)  Año 2023 (%)  \
# 0                  Data Scientist         19.57           NaN           NaN
# 1                   Data Engineer         13.04           NaN           NaN
# 2       Machine Learning Engineer         13.04           NaN           NaN
# 3                    Data Analyst         13.04           NaN           NaN
# 4         Data Science Consultant          8.70           NaN           NaN
# 5                  Data Scientist           NaN         25.00           NaN
# 6                   Data Engineer           NaN         21.55           NaN
# 7                    Data Analyst           NaN         14.66           NaN
# 8       Machine Learning Engineer           NaN          8.62           NaN
# 9                    AI Scientist           NaN          2.59           NaN
# 10                   Data Analyst           NaN           NaN         34.48
# ...

# %%
# Definir los datos
job_titles = nuevo_dataset_entry_level['Job Title']
porcentajes_por_año = nuevo_dataset_entry_level.drop(columns='Job Title')

# Crear la gráfica de barras apiladas
plt.figure(figsize=(10, 6))
porcentajes_por_año.plot(kind='bar', stacked=True)
plt.title('Porcentaje de frecuencia de job titles por año (Nivel de experiencia: Entry level)')
plt.xlabel('Job Title')
plt.ylabel('Porcentaje de frecuencia (%)')
plt.xticks(range(len(job_titles)), job_titles, rotation=45, ha='right')
plt.legend(title='Año')
plt.tight_layout()
plt.show()

# %% [markdown]
# Examinemos el tema del trabajo remoto.

# %%
# Contar el número de trabajadores con lugar de residencia distinto al de su empresa
trabajadores_distinto_pais = (data['employee_residence'] != data['company_location']).sum()

# Calcular el total de trabajadores
total_trabajadores = len(data)

# Calcular el porcentaje
porcentaje_distinto_pais = ((trabajadores_distinto_pais / total_trabajadores) * 100).round (2)

print("Cantidad de trabajadores con lugar de residencia distinto al de su empresa:", trabajadores_distinto_pais)
print("Total de trabajadores:", total_trabajadores)
print("Porcentaje de trabajadores con lugar de residencia distinto al de su empresa:", porcentaje_distinto_pais, "%")
# Out:
# Cantidad de trabajadores con lugar de residencia distinto al de su empresa: 129
# Total de trabajadores: 15486
# Porcentaje de trabajadores con lugar de residencia distinto al de su empresa: 0.83 %

# %%
# Mapear los valores de remote_ratio a las categorías específicas
data['trabajo_remoto'] = data['remote_ratio'].map({0: 'Sin trabajo remoto (menos del 20%)',
                                                    50: 'Parcialmente remoto/híbrido',
                                                    100: 'Totalmente remoto (más del 80%)'})

# Filtrar los datos para los años 2022, 2023 y 2024
datos_2022_2024 = data[data['work_year'].isin([2022, 2023, 2024])]

# Contar la cantidad total de cada categoría de trabajo remoto por año
trabajo_remoto_totales = datos_2022_2024.groupby(['work_year', 'trabajo_remoto']).size().unstack(fill_value=0)

# Mostrar la tabla
trabajo_remoto_totales
# Out:
# trabajo_remoto  Parcialmente remoto/híbrido  \
# work_year
# 2022                                     61
# 2023                                     72
# 2024                                     22
#
# trabajo_remoto  Sin trabajo remoto (menos del 20%)  \
# work_year
# 2022                                           709
# 2023                                          5775
# 2024                                          3798
#
# trabajo_remoto  Totalmente remoto (más del 80%)
# work_year
# 2022                                        885
# 2023                                       2672
# 2024                                       1199

# %%
# Calcular la suma total de trabajo remoto para cada año
suma_total_por_año = trabajo_remoto_totales.sum(axis=1)

# Calcular el porcentaje de cada categoría de trabajo remoto respecto al total del año
trabajo_remoto_porcentaje = (trabajo_remoto_totales.div(suma_total_por_año, axis=0) * 100).round(2)

# Mostrar la tabla con las cifras en porcentaje
trabajo_remoto_porcentaje
# Out:
# trabajo_remoto  Parcialmente remoto/híbrido  \
# work_year
# 2022                                   3.69
# 2023                                   0.85
# 2024                                   0.44
#
# trabajo_remoto  Sin trabajo remoto (menos del 20%)  \
# work_year
# 2022                                         42.84
# 2023                                         67.79
# 2024                                         75.67
#
# trabajo_remoto  Totalmente remoto (más del 80%)
# work_year
# 2022                                      53.47
# 2023                                      31.37
# 2024                                      23.89

# %%
# Graficar un gráfico de barras apiladas
trabajo_remoto_porcentaje.plot(kind='bar', stacked=True, figsize=(10, 6))

# Añadir etiquetas y título
plt.title('Porcentaje de Trabajo Remoto por Año')
plt.xlabel('Año')
plt.ylabel('Porcentaje')
plt.legend(title='Categoría de Trabajo Remoto')

# Mostrar la gráfica
plt.show()

# %%
# Graficar un gráfico de área apilada
ax = trabajo_remoto_porcentaje.plot(kind='area', stacked=True, figsize=(10, 6))

# Añadir etiquetas y título
plt.title('Porcentaje de Trabajo Remoto por Año')
plt.xlabel('Año')
plt.ylabel('Porcentaje')

# Centrar la leyenda
ax.legend(title='Categoría de Trabajo Remoto', loc='upper center', bbox_to_anchor=(0.5, -0.15), shadow=True, ncol=3)

# Mostrar la gráfica
plt.show()

# %%
# Filtrar los datos para la categoría "Data Analyst" y los años 2022, 2023 y 2024
data_analyst_data = data[(data['job_title'] == 'Data Analyst') & data['work_year'].isin([2022, 2023, 2024])]

# Contar la cantidad total de cada categoría de trabajo remoto por año
data_analyst_trabajo_remoto = data_analyst_data.groupby(['work_year', 'trabajo_remoto']).size().unstack(fill_value=0)

# Calcular el porcentaje de cada categoría de trabajo remoto respecto al total del año
data_analyst_porcentaje = data_analyst_trabajo_remoto.div(data_analyst_trabajo_remoto.sum(axis=1), axis=0) * 100

# Graficar un gráfico de área apilada
ax = data_analyst_porcentaje.plot(kind='area', stacked=True, figsize=(10, 6))

# Añadir etiquetas y título
plt.title('Porcentaje de Trabajo Remoto para Data Analyst por Año')
plt.xlabel('Año')
plt.ylabel('Porcentaje')

# Centrar la leyenda
ax.legend(title='Categoría de Trabajo Remoto', loc='upper center', bbox_to_anchor=(0.5, -0.15), shadow=True, ncol=3)

# Mostrar solo los años 2022, 2023 y 2024 en el eje x
plt.xticks(['2022', '2023', '2024'])

# Mostrar la gráfica
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\ferna\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axis.py:1769, in Axis.convert_units(self, x)
#    1768 try:
# -> 1769     ret = self.converter.convert(x, self.units, self)
#    1770 except Exception as e:
#
# File c:\Users\ferna\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\category.py:49, in StrCategoryConverter.convert(value, unit, axis)
#      48 if unit is None:
# ---> 49     raise ValueError(
#      50         'Missing category information for StrCategoryConverter; '
#      51         'this might be caused by unintendedly mixing categorical and '
#      52         'numeric data')
#      53 StrCategoryConverter._validate_unit(unit)
#
# ...

# %%
# Filtrar los datos para incluir solo los de los Estados Unidos
data_us = df_filtrado[df_filtrado['employee_residence'] == 'US']

# Dividir los datos en tres grupos: sin trabajo remoto, parcialmente remoto y totalmente remoto
sin_remoto = data_us[data_us['remote_ratio'] == 0]
parcialmente_remoto = data_us[data_us['remote_ratio'] == 50]
totalmente_remoto = data_us[data_us['remote_ratio'] == 100]

# Calcular el salario medio para cada grupo y para cada puesto de trabajo
salario_medio_sin_remoto = sin_remoto.groupby('job_title')['salary_in_usd'].mean()
salario_medio_parcialmente_remoto = parcialmente_remoto.groupby('job_title')['salary_in_usd'].mean()
salario_medio_totalmente_remoto = totalmente_remoto.groupby('job_title')['salary_in_usd'].mean()

# Mostrar los resultados
print("Salario medio sin trabajo remoto:")
print(salario_medio_sin_remoto)
print("\nSalario medio parcialmente remoto:")
print(salario_medio_parcialmente_remoto)
print("\nSalario medio totalmente remoto:")
print(salario_medio_totalmente_remoto)
# Out:
# Salario medio sin trabajo remoto:
# job_title
# Data Analyst                 112453.420717
# Data Engineer                153374.452551
# Data Scientist               164114.288440
# Machine Learning Engineer    196930.737523
# Name: salary_in_usd, dtype: float64
#
# Salario medio parcialmente remoto:
# job_title
# Data Analyst                  66666.666667
# Data Engineer                 90000.000000
# Data Scientist                89333.333333
# Machine Learning Engineer    156333.333333
# Name: salary_in_usd, dtype: float64
#
# Salario medio totalmente remoto:
# job_title
# Data Analyst                 112427.524259
# Data Engineer                155346.082965
# Data Scientist               162410.016538
# Machine Learning Engineer    192504.550595
# Name: salary_in_usd, dtype: float64

# %%
# Grafica Salario Medio por Categoría de Trabajo Remoto y Puesto de Trabajo
# Datos proporcionados
salario_medio_sin_remoto = {
    'Data Analyst': 112453.42,
    'Data Engineer': 153374.45,
    'Data Scientist': 164114.29,
    'Machine Learning Engineer': 196930.74
}

salario_medio_parcialmente_remoto = {
    'Data Analyst': 66666.67,
    'Data Engineer': 90000.00,
    'Data Scientist': 89333.33,
    'Machine Learning Engineer': 156333.33
}

salario_medio_totalmente_remoto = {
    'Data Analyst': 112427.52,
    'Data Engineer': 155346.08,
    'Data Scientist': 162410.02,
    'Machine Learning Engineer': 192504.55
}

# Puestos de trabajo
puestos_trabajo = list(salario_medio_sin_remoto.keys())

# Coordenadas x para las barras
x = np.arange(len(puestos_trabajo))

# Ancho de las barras
width = 0.25

# Crear la gráfica
fig, ax = plt.subplots(figsize=(10, 6))

# Graficar las barras para cada categoría de trabajo remoto
bar1 = ax.bar(x - width, list(salario_medio_sin_remoto.values()), width, label='Sin trabajo remoto')
bar2 = ax.bar(x, list(salario_medio_parcialmente_remoto.values()), width, label='Parcialmente remoto')
bar3 = ax.bar(x + width, list(salario_medio_totalmente_remoto.values()), width, label='Totalmente remoto')

# Personalizar la gráfica
ax.set_xlabel('Puesto de Trabajo')
ax.set_ylabel('Salario Medio (USD)')
ax.set_title('Salario Medio por Categoría de Trabajo Remoto y Puesto de Trabajo')
ax.set_xticks(x)
ax.set_xticklabels(puestos_trabajo, rotation=45, ha='right')
ax.legend()

# Mostrar la gráfica
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Resultados y Conclusiones

# %% [markdown]
# ## En conjunto podemos considerar que las siguientes hipótesis se apoyan en los datos:
#
# - Hipótesis 1: Los salarios iniciales varían significativamente según factores como la ubicación geográfica, el tipo de empresa y el nivel de experiencia.
#
# - Hipótesis 2: Los salarios iniciales en ciencia de datos son más altos en países con un fuerte desarrollo tecnológico, como Estados Unidos, Reino Unido o Canadá, en comparación con países en vías de desarrollo.
#
# - Hipótesis 3: Las posiciones de nivel de entrada en ciencia de datos, como analista de datos, científico de datos junior o ingeniero de datos junior, son las más comunes entre los recién graduados o aquellos con poca experiencia laboral.
#
# - Hipótesis 5: Los salarios iniciales en ciencia de datos tienden a aumentar significativamente con la experiencia, lo que indica una fuerte correlación entre la experiencia laboral y la compensación salarial en este campo.
#
# Mientras que la Hipótesis 4 no encuentra apoyo o es refutada por los datos:
#
# - Hipótesis 4: Las empresas que ofrecen una mayor proporción de trabajo remoto tienden a pagar salarios más altos para los roles de entrada en ciencia de datos, ya que pueden acceder a un pool más amplio de talentos sin las restricciones geográficas.

# %% [markdown]
# ### Conclusiones
#
# Después de realizar el análisis exploratorio de datos, podemos extraer varias conclusiones importantes:
#
# - Es probable que comiences tu carrera profesional en roles como Data Analyst, Data Scientist, Data Engineer o Machine Learning Engineer.
# - Los salarios tienden a ser más altos en Estados Unidos en comparación con otros países.
# - Existe una correlación significativa entre la experiencia laboral y la compensación salarial, lo que indica que la experiencia se paga en este campo.
# - Aunque las empresas grandes pueden ofrecer beneficios adicionales, no siempre son las que mejor pagan en términos de salario inicial.
# - El trabajo remoto no siempre es tan sencillo como se puede pensar inicialmente. Requiere adaptación tanto por parte de los empleados como de las empresas.
# - El trabajo híbrido, que combina el trabajo presencial con el trabajo remoto, también presenta desafíos únicos y puede no ser la solución ideal para todos los casos.
#
# Estas conclusiones proporcionan una visión general de las tendencias y características importantes del mercado laboral en el campo de la ciencia de datos.

# %% [markdown]
# ### Basándome en esas conclusiones, aquí tienes algunas recomendaciones:
#
# 1. **Enfoque en la experiencia y habilidades**: Independientemente de tu rol inicial (Data Analyst, Data Scientist, Data Engineer o Machine Learning Engineer), concéntrate en ganar experiencia y desarrollar habilidades sólidas en tu área. La experiencia y la demostración de habilidades son clave para avanzar en tu carrera y obtener mejores oportunidades laborales y salariales.
#
# 2. **Considera oportunidades internacionales**: Si estás dispuesto a mudarte y tienes un buen dominio del inglés, considera buscar oportunidades en los Estados Unidos u otros países donde los salarios para roles en data science suelen ser más altos. Ampliar tus horizontes geográficos puede abrirte puertas a mejores oportunidades profesionales y financieras.
#
# 3. **Investiga las empresas**: No asumas que las empresas grandes siempre son las que mejor pagan. Realiza una investigación exhaustiva sobre las empresas que te interesan, incluso las más pequeñas o menos conocidas, ya que algunas pueden ofrecer salarios competitivos y un ambiente de trabajo favorable para el crecimiento profesional.
#
# 4. **Prepárate para los desafíos del trabajo remoto y híbrido**: Si estás considerando opciones de trabajo remoto o híbrido, sé consciente de que puede no ser tan fácil como parece. Asegúrate de tener las habilidades necesarias para trabajar de manera efectiva de forma remota, como la capacidad de comunicarte de manera clara y colaborar en entornos virtuales. Además, prepárate para los desafíos que pueden surgir al equilibrar el trabajo remoto con la vida personal y establece límites claros para mantener un equilibrio saludable.
#
# En resumen, busca ganar experiencia, considera oportunidades internacionales si es posible, investiga las empresas cuidadosamente y prepárate para los desafíos del trabajo remoto y híbrido. Estas recomendaciones pueden ayudarte a tomar decisiones informadas y avanzar en tu carrera en el área de data science.
